# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
pd.__version__
# Out:
# '1.4.2'

# %%
np.__version__
# Out:
# '1.22.2'

# %%
df = pd.read_csv("jetson_xivir_log.csv")

# %%
df.head()
# Out:
#                          time          uptime jetson_clocks       nvp model  \
# 0  2022-03-31 12:23:36.214635  1:07:06.860000           OFF  MODE_15W_6CORE
# 1  2022-03-31 12:23:36.217505  1:07:06.870000           OFF  MODE_15W_6CORE
# 2  2022-03-31 12:23:36.790891  1:07:07.440000           OFF  MODE_15W_6CORE
# 3  2022-03-31 12:23:37.307437  1:07:07.960000           OFF  MODE_15W_6CORE
# 4  2022-03-31 12:23:37.848633  1:07:08.500000           OFF  MODE_15W_6CORE
#
#    CPU1  CPU2  CPU3  CPU4  CPU5  CPU6  ...  NVDEC  NVJPG        fan  Temp AO  \
# 0    49    48    37    41    69    38  ...    OFF    OFF  50.980392     49.0
# 1    49    48    37    41    69    38  ...    OFF    OFF  50.980392     49.0
# 2    73    60    62    57    82    52  ...    OFF    OFF   0.000000     43.0
# 3    90    44    75    63    39    46  ...    OFF    OFF   0.000000     43.0
# 4    48    40    56    48    40    61  ...    OFF    OFF   0.000000     43.0
#
#    Temp AUX  Temp CPU  Temp GPU Temp thermal power cur power avg
# 0      48.5      52.0      51.5        50.45     12189     12143
# 1      48.5      52.0      51.5        50.45     12189     12143
# 2      42.5      46.0      45.0        43.95     12393     12393
# 3      42.5      46.0      45.5        44.45     12189     12291
# 4      43.0      46.5      45.5        44.45     12148     12243
#
# [5 rows x 28 columns]

# %%
for i in range(1,7):
    try:
        ax = df.plot(x="time", y="CPU"+str(i), style='b')
        ax.set_ylabel('CPU'+str(i))
    except:
        pass

# df.plot(x="time", y="CPU1", style='g')
# df.plot(x="time", y="CPU1", style='g')
# df.plot(x="time", y="CPU1", style='g')

# %%
j=0
for i in range(1,7):
    print(i, j)
    j+=1
# Out:
# 1 0
# 2 1
# 3 2
# 4 3
# 5 4
# 6 5

# %%
i=1
fig, axes = plt.subplots(nrows=3, ncols=2)
df["CPU"+str(i)].plot(ax=axes[0,0]); axes[0,0].set_title("CPU"+str(i))
# Out:
# Text(0.5, 1.0, 'CPU1')

# %%
k=1
fig, axes = plt.subplots(nrows=3, ncols=2)
for i in range(3):
    for j in range(2):
        # print(i,j)
        try:
            df['CPU'+str(k)].plot(ax=axes[i,j], style='b'); axes[i,j].set_title('CPU'+str(k))
            k+=1
        except:
            pass
        
# for i in range(1,7):
#     df["CPU"+str(i)].plot(ax=axes[j,0]); axes[0,0].set_title("CPU"+str(i))
#     print(i, j)
#     j+=1

# %%
df = pd.read_csv("nano_log.csv")
k=1
fig, axes = plt.subplots(nrows=3, ncols=2)
for i in range(3):
    for j in range(2):
        # print(i,j)
        try:
            df['CPU'+str(k)].plot(ax=axes[i,j], style='b'); axes[i,j].set_title('CPU'+str(k))
            k+=1
        except:
            pass

# %%
df.head()
# Out:
#                          time          uptime jetson_clocks nvp model  CPU1  \
# 0  2022-04-04 11:24:22.164103  0:08:29.700000           OFF      MAXN    24
# 1  2022-04-04 11:24:22.165443  0:08:29.710000           OFF      MAXN    24
# 2  2022-04-04 11:24:22.666269  0:08:30.210000           OFF      MAXN    20
# 3  2022-04-04 11:24:23.173194  0:08:30.710000           OFF      MAXN     9
# 4  2022-04-04 11:24:23.678795  0:08:31.220000           OFF      MAXN     2
#
#    CPU2  CPU3  CPU4  GPU      RAM  ...  NVDEC  NVJPG  fan  Temp AO Temp CPU  \
# 0    37    46    35    0  1667752  ...    OFF    OFF  0.0     47.0     42.5
# 1    37    46    35    0  1667752  ...    OFF    OFF  0.0     47.0     42.5
# 2     8    25    16    2  1662288  ...    OFF    OFF  0.0     47.0     41.0
# 3     9    11    11    1  1662724  ...    OFF    OFF  0.0     47.0     41.0
# 4     4     2     4    0  1661872  ...    OFF    OFF  0.0     47.0     41.0
#
#   Temp GPU Temp PLL  Temp thermal  power cur  power avg
# 0     41.0     38.5          41.0       3002       3002
# 1     41.0     38.5          41.0       3002       3002
# 2     41.0     38.5          41.0       2119       2560
# 3     40.5     38.5          40.5       2799       2640
# 4     40.5     38.5          40.5       1997       2479
#
# [5 rows x 25 columns]

# %%
df.columns.values
# Out:
# array(['time', 'uptime', 'jetson_clocks', 'nvp model', 'CPU1', 'CPU2',
#        'CPU3', 'CPU4', 'GPU', 'RAM', 'EMC', 'IRAM', 'SWAP', 'APE',
#        'NVENC', 'NVDEC', 'NVJPG', 'fan', 'Temp AO', 'Temp CPU',
#        'Temp GPU', 'Temp PLL', 'Temp thermal', 'power cur', 'power avg'],
#       dtype=object)

# %%
t = ['CPU1', 'CPU2','CPU3','CPU4','CPU5','CPU6','GPU', 'RAM','EMC', 'IRAM', 'Temp AO', 'Temp CPU', 'Temp GPU', 'Temp PLL', 'Temp thermal', 'power cur', 'power avg','fan']

# %%
len(t)
# Out:
# 18

# %%
for it in t:
    try:
        ax = df.plot(x="time", y=it, style='b')
        ax.set_ylabel(it)
    except:
        pass

# %%
fig, axes = plt.subplots(nrows=6, ncols=3)
k = 0
fig = plt.figure()
spacing = 0.100
for i in range(6):
    for j in range(3):
        # print(i,j)
        try:
            df[t[k]].plot(ax=axes[i,j], style='b'); axes[i,j].set_title(t[k])
            k+=1
        except:
            k+=1
# set the spacing between subplots
plt.subplots_adjust(left=0.1,
                    bottom=0.1, 
                    right=0.9, 
                    top=0.9, 
                    wspace=0.9, 
                    hspace=0.9)
plt.show()

# %%
df = pd.read_csv("jetson_xivir_log.csv")
t = ['CPU1', 'CPU2','CPU3','CPU4','CPU5','CPU6','GPU', 'RAM','EMC', 'IRAM', 'Temp AO', 'Temp CPU', 'Temp GPU', 'Temp PLL', 'Temp thermal', 'power cur', 'power avg','fan']
for it in t:
    try:
        ax = df.plot(x="time", y=it, style='b')
        ax.set_ylabel(it)
    except:
        pass
plt.show()

fig, axes = plt.subplots(nrows=6, ncols=3)
k = 0
fig = plt.figure()
spacing = 0.100
for i in range(6):
    for j in range(3):
        # print(i,j)
        try:
            df[t[k]].plot(ax=axes[i,j], style='b'); axes[i,j].set_title(t[k])
            k+=1
        except:
            k+=1
# set the spacing between subplots
plt.subplots_adjust(left=0.1,
                    bottom=0.1, 
                    right=0.9, 
                    top=0.9, 
                    wspace=0.9, 
                    hspace=0.9)
plt.show()
