# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline


def jetson_viz(df):
    
    names = df.columns.unique().tolist()
    for it in names:
        try:
            print("Max"+str(it)+"----->",np.max(df[str(it)]))
            print("Min"+str(it)+"----->",np.min(df[str(it)]))
            print("Avg"+str(it)+"----->",np.average(df[str(it)]))
            print("\n")
            ax = df.plot(x="time", y=it, style='b')
            ax.set_ylabel(it)
            plt.show()
            print("--------------------------------------------------------------------------------------------------------------- \n")
        except:
            pass
    plt.show()
df = pd.read_csv(str("data/log.csv"))

# %%
jetson_viz(df)
# Out:
# Maxtime-----> 2022-04-05 16:29:08.853261
# Mintime-----> 2022-04-05 16:27:38.683774
# Maxuptime-----> 0:42:43.190000
# Minuptime-----> 0:41:13.020000
# Maxjetson_clocks-----> OFF
# Minjetson_clocks-----> OFF
# Maxnvp model-----> MAXN
# Minnvp model-----> MAXN
# MaxCPU1-----> 46
# MinCPU1-----> 19
# AvgCPU1-----> 34.29050279329609
# ---------------------------------------------------------------------------------------------------------------
#
# MaxCPU2-----> 69
# MinCPU2-----> 16
# AvgCPU2-----> 31.51396648044693
# ---------------------------------------------------------------------------------------------------------------
#
# MaxCPU3-----> 58
# MinCPU3-----> 20
# AvgCPU3-----> 30.11731843575419
# ---------------------------------------------------------------------------------------------------------------
#
# MaxCPU4-----> 100
# MinCPU4-----> 16
# AvgCPU4-----> 30.24022346368715
# ...
