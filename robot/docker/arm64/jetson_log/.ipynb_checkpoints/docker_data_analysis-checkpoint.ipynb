# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
# %matplotlib inline

# %%
def docker_viz(df):
    t = ["cpu_percentage", "mem_percentage", "mem_usage", "mem_limit"]
    for it in t:
        try:
            ax = df.plot(y=it, style='b')
            ax.set_ylabel(it)
        except:
            pass
    plt.show()

    fig, axes = plt.subplots(nrows=2, ncols=2)
    k = 0
    fig = plt.figure()
    spacing = 0.100
    for i in range(2):
        for j in range(2):
            # print(i,j)
            try:
                df[t[k]].plot(ax=axes[i,j], style='b'); axes[i,j].set_title(t[k])
                k+=1
            except:
                k+=1
    # set the spacing between subplots
    plt.subplots_adjust(left=0.1,
                        bottom=0.1, 
                        right=0.9, 
                        top=0.9, 
                        wspace=0.9, 
                        hspace=0.9)
    plt.show()

# %%
# Parse the data
def percentage_to_float(df_col):
    return df_col.apply(lambda x: float(x[0:-1]))

def split_on_slash(df_col, split_index):
    return df_col.apply(lambda x: x.split(" / ")[split_index])

def get_only_characters(string):
    return re.sub('[^a-zA-Z]+', '', string)

def get_only_numbers(string):
    return float(re.sub('[^\d\.]', '', string))

def to_bit(value):
    return int({
        "b": get_only_numbers(value) * 1,
        "kib": get_only_numbers(value) * 10e3,
        "kb": get_only_numbers(value) * 10e3,
        "mib": get_only_numbers(value) * 10e6,
        "mb": get_only_numbers(value) * 10e6,
        "gib": get_only_numbers(value) * 10e9,
        "gb": get_only_numbers(value) * 10e9,
    }.get(get_only_characters(value).lower(), 0))

def pre_processing(df):
    df = df[df["CPU %"] != "CPU %"]
    df["cpu_percentage"] = percentage_to_float(df["CPU %"])
    df["mem_percentage"] = percentage_to_float(df["MEM %"])
    df["mem_usage"] = split_on_slash(df["MEM USAGE / LIMIT"], 0).apply(to_bit)
    df["mem_limit"] = split_on_slash(df["MEM USAGE / LIMIT"], 1).apply(to_bit)
    return df
df = pd.read_csv("docker_stats.csv")
df = pre_processing(df)
# Out:
# /tmp/ipykernel_57050/816572094.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["cpu_percentage"] = percentage_to_float(df["CPU %"])
# /tmp/ipykernel_57050/816572094.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["mem_percentage"] = percentage_to_float(df["MEM %"])
# /tmp/ipykernel_57050/816572094.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["mem_usage"] = split_on_slash(df["MEM USAGE / LIMIT"], 0).apply(to_bit)
# /tmp/ipykernel_57050/816572094.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["mem_limit"] = split_on_slash(df["MEM USAGE / LIMIT"], 1).apply(to_bit)

# %%
docker_viz(df)

# %%
# while true; do docker stats --no-stream | tee --append stats.txt; sleep 1; done
df = pd.read_csv("docker_stats.csv")

# %%
df
# Out:
#                          NAME    CPU %   MEM %    MEM USAGE / LIMIT
# 0    arm64_sar_ros2_zed_run_1  129.10%  28.65%  1.107GiB / 3.863GiB
# 1                        NAME    CPU %   MEM %    MEM USAGE / LIMIT
# 2    arm64_sar_ros2_zed_run_1  127.88%  28.63%  1.106GiB / 3.863GiB
# 3                        NAME    CPU %   MEM %    MEM USAGE / LIMIT
# 4    arm64_sar_ros2_zed_run_1  131.20%  28.63%  1.106GiB / 3.863GiB
# ..                        ...      ...     ...                  ...
# 308  arm64_sar_ros2_zed_run_1  130.79%  27.75%  1.072GiB / 3.863GiB
# 309               NAME    CPU %   MEM %    MEM USAGE / LIMIT
# 310  arm64_sar_ros2_zed_run_1  130.79%  27.75%  1.072GiB / 3.863GiB
# 311               NAME    CPU %   MEM %    MEM USAGE / LIMIT
# 312  arm64_sar_ros2_zed_run_1  130.79%  27.75%  1.072GiB / 3.863GiB
#
# [313 rows x 4 columns]

# %%
# Remove repeating headers
df = df[df["CPU %"] != "CPU %"]

# %%
df
# Out:
#                          NAME    CPU %   MEM %    MEM USAGE / LIMIT
# 0    arm64_sar_ros2_zed_run_1  129.10%  28.65%  1.107GiB / 3.863GiB
# 2    arm64_sar_ros2_zed_run_1  127.88%  28.63%  1.106GiB / 3.863GiB
# 4    arm64_sar_ros2_zed_run_1  131.20%  28.63%  1.106GiB / 3.863GiB
# 6    arm64_sar_ros2_zed_run_1  132.65%  28.63%  1.106GiB / 3.863GiB
# 8    arm64_sar_ros2_zed_run_1  132.04%  28.63%  1.106GiB / 3.863GiB
# ..                        ...      ...     ...                  ...
# 304  arm64_sar_ros2_zed_run_1  115.63%  27.75%  1.072GiB / 3.863GiB
# 306  arm64_sar_ros2_zed_run_1  115.63%  27.75%  1.072GiB / 3.863GiB
# 308  arm64_sar_ros2_zed_run_1  130.79%  27.75%  1.072GiB / 3.863GiB
# 310  arm64_sar_ros2_zed_run_1  130.79%  27.75%  1.072GiB / 3.863GiB
# 312  arm64_sar_ros2_zed_run_1  130.79%  27.75%  1.072GiB / 3.863GiB
#
# [157 rows x 4 columns]

# %%
# Parse the data
def percentage_to_float(df_col):
    return df_col.apply(lambda x: float(x[0:-1]))

def split_on_slash(df_col, split_index):
    return df_col.apply(lambda x: x.split(" / ")[split_index])

def get_only_characters(string):
    return re.sub('[^a-zA-Z]+', '', string)

def get_only_numbers(string):
    return float(re.sub('[^\d\.]', '', string))

def to_bit(value):
    return int({
        "b": get_only_numbers(value) * 1,
        "kib": get_only_numbers(value) * 10e3,
        "kb": get_only_numbers(value) * 10e3,
        "mib": get_only_numbers(value) * 10e6,
        "mb": get_only_numbers(value) * 10e6,
        "gib": get_only_numbers(value) * 10e9,
        "gb": get_only_numbers(value) * 10e9,
    }.get(get_only_characters(value).lower(), 0))

# %%
df["cpu_percentage"] = percentage_to_float(df["CPU %"])
df["mem_percentage"] = percentage_to_float(df["MEM %"])
df["mem_usage"] = split_on_slash(df["MEM USAGE / LIMIT"], 0).apply(to_bit)
df["mem_limit"] = split_on_slash(df["MEM USAGE / LIMIT"], 1).apply(to_bit)
# Out:
# /tmp/ipykernel_51316/1323715373.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["cpu_percentage"] = percentage_to_float(df["CPU %"])
# /tmp/ipykernel_51316/1323715373.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["mem_percentage"] = percentage_to_float(df["MEM %"])
# /tmp/ipykernel_51316/1323715373.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["mem_usage"] = split_on_slash(df["MEM USAGE / LIMIT"], 0).apply(to_bit)
# /tmp/ipykernel_51316/1323715373.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["mem_limit"] = split_on_slash(df["MEM USAGE / LIMIT"], 1).apply(to_bit)

# %%
def docker_viz(df):
    t = ["cpu_percentage", "mem_percentage", "mem_usage", "mem_limit"]
    for it in t:
        try:
            ax = df.plot(y=it, style='b')
            ax.set_ylabel(it)
        except:
            pass
    plt.show()

    fig, axes = plt.subplots(nrows=2, ncols=2)
    k = 0
    fig = plt.figure()
    spacing = 0.100
    for i in range(2):
        for j in range(2):
            # print(i,j)
            try:
                df[t[k]].plot(ax=axes[i,j], style='b'); axes[i,j].set_title(t[k])
                k+=1
            except:
                k+=1
    # set the spacing between subplots
    plt.subplots_adjust(left=0.1,
                        bottom=0.1, 
                        right=0.9, 
                        top=0.9, 
                        wspace=0.9, 
                        hspace=0.9)
    plt.show()

# %%
docker_viz(df)
