# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline


def jetson_viz(df):
    
    names = df.columns.unique().tolist()
    for it in names:
        try:
            print("Max"+str(it)+"----->",np.max(df[str(it)]))
            print("Min"+str(it)+"----->",np.min(df[str(it)]))
            print("Avg"+str(it)+"----->",np.average(df[str(it)]))
            print("\n")
            ax = df.plot(x="time", y=it, style='b')
            ax.set_ylabel(it)
            plt.show()
            print("--------------------------------------------------------------------------------------------------------------- \n")
        except:
            pass
    plt.show()
df = pd.read_csv(str("data/log.csv"))

# %%
jetson_viz(df)
# Out:
# Maxtime-----> 2022-04-05 12:25:57.156601
# Mintime-----> 2022-04-05 12:17:47.839228
# Maxuptime-----> 0:18:38.640000
# Minuptime-----> 0:10:29.330000
# Maxjetson_clocks-----> OFF
# Minjetson_clocks-----> OFF
# Maxnvp model-----> MAXN
# Minnvp model-----> MAXN
# MaxCPU1-----> 58
# MinCPU1-----> 19
# AvgCPU1-----> 32.357588357588355
# ---------------------------------------------------------------------------------------------------------------
#
# MaxCPU2-----> 54
# MinCPU2-----> 15
# AvgCPU2-----> 30.671517671517673
# ---------------------------------------------------------------------------------------------------------------
#
# MaxCPU3-----> 44
# MinCPU3-----> 17
# AvgCPU3-----> 28.913721413721415
# ---------------------------------------------------------------------------------------------------------------
#
# MaxCPU4-----> 45
# MinCPU4-----> 15
# AvgCPU4-----> 28.244282744282746
# ---------------------------------------------------------------------------------------------------------------
#
# MaxGPU-----> 38
# MinGPU-----> 0
# AvgGPU-----> 1.528066528066528
# ---------------------------------------------------------------------------------------------------------------
#
# MaxRAM-----> 1805052
# MinRAM-----> 1722780
# AvgRAM-----> 1763842.656964657
# ---------------------------------------------------------------------------------------------------------------
#
# MaxEMC-----> 1805052
# MinEMC-----> 1722780
# AvgEMC-----> 1763842.656964657
# ---------------------------------------------------------------------------------------------------------------
#
# MaxIRAM-----> 1805052
# MinIRAM-----> 1722780
# AvgIRAM-----> 1763842.656964657
# ---------------------------------------------------------------------------------------------------------------
#
# MaxSWAP-----> 0
# MinSWAP-----> 0
# AvgSWAP-----> 0.0
# ---------------------------------------------------------------------------------------------------------------
#
# MaxAPE-----> 25
# MinAPE-----> 25
# AvgAPE-----> 25.0
# ---------------------------------------------------------------------------------------------------------------
#
# MaxNVENC-----> OFF
# MinNVENC-----> OFF
# MaxNVDEC-----> OFF
# MinNVDEC-----> OFF
# MaxNVJPG-----> OFF
# MinNVJPG-----> OFF
# Maxfan-----> 0.0
# Minfan-----> 0.0
# Avgfan-----> 0.0
# ---------------------------------------------------------------------------------------------------------------
#
# MaxTemp AO-----> 39.5
# MinTemp AO-----> 35.5
# AvgTemp AO-----> 37.91735966735967
# ---------------------------------------------------------------------------------------------------------------
#
# MaxTemp CPU-----> 36.5
# MinTemp CPU-----> 32.5
# AvgTemp CPU-----> 34.49948024948025
# ---------------------------------------------------------------------------------------------------------------
#
# MaxTemp GPU-----> 34.5
# MinTemp GPU-----> 29.5
# AvgTemp GPU-----> 31.216216216216218
# ---------------------------------------------------------------------------------------------------------------
#
# MaxTemp PLL-----> 33.0
# MinTemp PLL-----> 29.0
# AvgTemp PLL-----> 31.10706860706861
# ---------------------------------------------------------------------------------------------------------------
#
# MaxTemp thermal-----> 35.0
# MinTemp thermal-----> 31.0
# AvgTemp thermal-----> 32.857588357588355
# ---------------------------------------------------------------------------------------------------------------
#
# Maxpower cur-----> 3246
# Minpower cur-----> 1528
# Avgpower cur-----> 2105.1808731808733
# ---------------------------------------------------------------------------------------------------------------
#
# Maxpower avg-----> 2995
# Minpower avg-----> 2079
# Avgpower avg-----> 2097.1091476091474
# ---------------------------------------------------------------------------------------------------------------
